# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/university-salaries/university-salaries/data_dictionary.csv
# /kaggle/input/university-salaries/university-salaries/salaries_final.csv
# /kaggle/input/university-salaries/university-salaries/salaries_without_dept.csv

# %%
df = pd.read_csv("/kaggle/input/university-salaries/university-salaries/salaries_final.csv")
df.head()
# Out:
#    Year              Name    Primary Job Title  Base Pay  \
# 0  2010  Abaied, Jamie L.  Assistant Professor   64000.0
# 1  2011  Abaied, Jamie L.  Assistant Professor   64000.0
# 2  2012  Abaied, Jamie L.  Assistant Professor   65229.0
# 3  2013  Abaied, Jamie L.  Assistant Professor   66969.0
# 4  2014  Abaied, Jamie L.  Assistant Professor   68658.0
#
#                             Department College
# 0  Department of Psychological Science     CAS
# 1  Department of Psychological Science     CAS
# 2  Department of Psychological Science     CAS
# 3  Department of Psychological Science     CAS
# 4  Department of Psychological Science     CAS

# %%
A = df[(df['College'] != 'LCOMEO')&(df['College'] != 'Department of Ext')&(df['College'] != 'Learning and Info Tech')&(df['College'] != 'Library')]
A
# Out:
#        Year                   Name    Primary Job Title  Base Pay  \
# 0      2010       Abaied, Jamie L.  Assistant Professor   64000.0
# 1      2011       Abaied, Jamie L.  Assistant Professor   64000.0
# 2      2012       Abaied, Jamie L.  Assistant Professor   65229.0
# 3      2013       Abaied, Jamie L.  Assistant Professor   66969.0
# 4      2014       Abaied, Jamie L.  Assistant Professor   68658.0
# ...     ...                    ...                  ...       ...
# 14465  2016  van der Vliet, Albert            Professor  163635.0
# 14466  2017  van der Vliet, Albert            Professor  175294.0
# 14467  2018  van der Vliet, Albert            Professor  191000.0
# 14468  2019  van der Vliet, Albert            Professor  196000.0
# 14469  2020  van der Vliet, Albert            Professor  186200.0
#
#                                         Department College
# 0              Department of Psychological Science     CAS
# 1              Department of Psychological Science     CAS
# 2              Department of Psychological Science     CAS
# 3              Department of Psychological Science     CAS
# 4              Department of Psychological Science     CAS
# ...                                            ...     ...
# 14465  Department of Pathology&Laboratory Medicine     COM
# 14466  Department of Pathology&Laboratory Medicine     COM
# 14467  Department of Pathology&Laboratory Medicine     COM
# 14468  Department of Pathology&Laboratory Medicine     COM
# 14469  Department of Pathology&Laboratory Medicine     COM
#
# [14203 rows x 6 columns]

# %%
B1 = A['Year'] >= 2017
A = A[B1]
A
# Out:
#        Year                            Name    Primary Job Title  Base Pay  \
# 7      2017                Abaied, Jamie L.  Associate Professor   79432.0
# 8      2018                Abaied, Jamie L.  Associate Professor   84603.0
# 9      2019                Abaied, Jamie L.  Associate Professor   67200.0
# 10     2020                Abaied, Jamie L.  Associate Professor   86934.0
# 17     2017           Abajian, Michael John             Lecturer   47345.0
# ...     ...                             ...                  ...       ...
# 14457  2020  van den Broek-Altenburg, Eline  Assistant Professor  123500.0
# 14466  2017           van der Vliet, Albert            Professor  175294.0
# 14467  2018           van der Vliet, Albert            Professor  191000.0
# 14468  2019           van der Vliet, Albert            Professor  196000.0
# 14469  2020           van der Vliet, Albert            Professor  186200.0
#
#                                         Department College
# 7              Department of Psychological Science     CAS
# 8              Department of Psychological Science     CAS
# 9              Department of Psychological Science     CAS
# 10             Department of Psychological Science     CAS
# 17                           Department of Nursing    CNHS
# ...                                            ...     ...
# 14457                      Department of Radiology     COM
# 14466  Department of Pathology&Laboratory Medicine     COM
# 14467  Department of Pathology&Laboratory Medicine     COM
# 14468  Department of Pathology&Laboratory Medicine     COM
# 14469  Department of Pathology&Laboratory Medicine     COM
#
# [6204 rows x 6 columns]

# %%
B = pd.pivot_table(A,index = ['College'],columns = ['Year'],values = ['Base Pay'],aggfunc=np.sum)
B
# Out:
#             Base Pay
# Year            2017        2018        2019        2020
# College
# Business   4438318.0   4936034.0   5111659.0   5121106.0
# CALS       5593542.0   6502689.0   7002761.0   7021049.0
# CAS       28527010.0  30553777.0  31146783.0  31815535.0
# CEMS       7558824.0   8653389.0   9076796.0   9826601.0
# CESS       4789916.0   5493019.0   5974718.0   6163987.0
# CNHS       3823123.0   4288527.0   4794891.0   5063849.0
# COM       39309480.0  43884747.0  49883868.0  52027371.0
# RSENR      3058523.0   3302336.0   3320626.0   3424403.0

# %%
B['Base Pay','Sum'] = B[('Base Pay',2017)] + B[('Base Pay',2018)] + B[('Base Pay',2019)] +B[('Base Pay',2020)]
B['Base Pay','Sum']
# Out:
# College
# Business     19607117.0
# CALS         26120041.0
# CAS         122043105.0
# CEMS         35115610.0
# CESS         22421640.0
# CNHS         17970390.0
# COM         185105466.0
# RSENR        13105888.0
# Name: (Base Pay, Sum), dtype: float64

# %%
B['Base Pay','%'] = round(B['Base Pay','Sum']*100/(B['Base Pay','Sum'].sum()),2)
B
# Out:
#             Base Pay
# Year            2017        2018        2019        2020          Sum      %
# College
# Business   4438318.0   4936034.0   5111659.0   5121106.0   19607117.0   4.44
# CALS       5593542.0   6502689.0   7002761.0   7021049.0   26120041.0   5.92
# CAS       28527010.0  30553777.0  31146783.0  31815535.0  122043105.0  27.64
# CEMS       7558824.0   8653389.0   9076796.0   9826601.0   35115610.0   7.95
# CESS       4789916.0   5493019.0   5974718.0   6163987.0   22421640.0   5.08
# CNHS       3823123.0   4288527.0   4794891.0   5063849.0   17970390.0   4.07
# COM       39309480.0  43884747.0  49883868.0  52027371.0  185105466.0  41.93
# RSENR      3058523.0   3302336.0   3320626.0   3424403.0   13105888.0   2.97

# %%
C = (B['Base Pay',2017].sum(),B['Base Pay',2018].sum(),B['Base Pay',2019].sum(),B['Base Pay',2020].sum())

# %%
D1 = round((C[1]-C[0])*100/C[0],2)
D2 = round((C[2]-C[1])*100/C[1],2)
D3 = round((C[3]-C[2])*100/C[2],2)
D4 = round((D1 + D2 + D3)/3,2)
D4
# Out:
# 7.49

# %%
B.loc[len(B.index)] = [0,D1,D2,D3,0,D4]

# %%
B.rename(index={8 : 'Growth'})
# Out:
#             Base Pay                                                      \
# Year            2017         2018         2019         2020          Sum
# College
# Business   4438318.0   4936034.00   5111659.00   5121106.00   19607117.0
# CALS       5593542.0   6502689.00   7002761.00   7021049.00   26120041.0
# CAS       28527010.0  30553777.00  31146783.00  31815535.00  122043105.0
# CEMS       7558824.0   8653389.00   9076796.00   9826601.00   35115610.0
# CESS       4789916.0   5493019.00   5974718.00   6163987.00   22421640.0
# CNHS       3823123.0   4288527.00   4794891.00   5063849.00   17970390.0
# COM       39309480.0  43884747.00  49883868.00  52027371.00  185105466.0
# RSENR      3058523.0   3302336.00   3320626.00   3424403.00   13105888.0
# Growth           0.0        10.83         8.08         3.57          0.0
#
#
# Year          %
# College
# Business   4.44
# CALS       5.92
# CAS       27.64
# CEMS       7.95
# CESS       5.08
# CNHS       4.07
# COM       41.93
# RSENR      2.97
# Growth     7.49
